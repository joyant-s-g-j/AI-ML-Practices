# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import csv

data = []

with open('Practice_Day_15_5.csv', 'r', newline='', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)
    n_cols = len(header)
    for row in reader:
        while len(row) < n_cols:
            row.append(pd.NA)
        if len(row) > n_cols:
            row = row[:n_cols]
        data.append(row)

df = pd.DataFrame(data, columns=header)
df
# Out:
#    EmployeeID EmployeeName Age Salary  Price Marks1 Marks2 Marks3
# 0        E101        Alice  25  50000   1200     85     90     88
# 1        E102          Bob  30         60000   1500     78     82
# 2        E103      Charlie  22  52000   1100     92     95     90
# 3        E101        Alice  25  50000   1200     85     90     88
# 4        E104        David  45  80000   2500     88     85     89
# 5        E105          Eve  29  58000   1300     76     79     81
# 6        E106        Frank      75000   2200     90     91     92
# 7        E107        Grace  34          1900     81     83     80
# 8        E108        Heidi  38          1800     84     86     88
# 9        E109         Ivan  26  53000   1400     95     92     94
# 10       E102          Bob  30         60000   1500     78     82

# %%
df['Price'] = pd.to_numeric(df['Price'])

dis = df['Price'] * 0.10

df['Discounted_Price'] = df['Price'] - dis

df
# Out:
#    EmployeeID EmployeeName Age Salary  Price Marks1 Marks2 Marks3  \
# 0        E101        Alice  25  50000   1200     85     90     88
# 1        E102          Bob  30         60000   1500     78     82
# 2        E103      Charlie  22  52000   1100     92     95     90
# 3        E101        Alice  25  50000   1200     85     90     88
# 4        E104        David  45  80000   2500     88     85     89
# 5        E105          Eve  29  58000   1300     76     79     81
# 6        E106        Frank      75000   2200     90     91     92
# 7        E107        Grace  34          1900     81     83     80
# 8        E108        Heidi  38          1800     84     86     88
# 9        E109         Ivan  26  53000   1400     95     92     94
# 10       E102          Bob  30         60000   1500     78     82
#
#     Discounted_Price
# 0             1080.0
# 1            54000.0
# 2              990.0
# 3             1080.0
# 4             2250.0
# 5             1170.0
# 6             1980.0
# 7             1710.0
# 8             1620.0
# 9             1260.0
# 10           54000.0

# %%
df.to_csv('discounted_products.csv')

# %%
df['EmployeeID'].duplicated().sum()
# Out:
# np.int64(2)

# %%
df_clean = df.drop_duplicates(subset='EmployeeID')

df_clean
# Out:
#   EmployeeID EmployeeName Age Salary  Price Marks1 Marks2 Marks3  \
# 0       E101        Alice  25  50000   1200     85     90     88
# 1       E102          Bob  30         60000   1500     78     82
# 2       E103      Charlie  22  52000   1100     92     95     90
# 4       E104        David  45  80000   2500     88     85     89
# 5       E105          Eve  29  58000   1300     76     79     81
# 6       E106        Frank      75000   2200     90     91     92
# 7       E107        Grace  34          1900     81     83     80
# 8       E108        Heidi  38          1800     84     86     88
# 9       E109         Ivan  26  53000   1400     95     92     94
#
#    Discounted_Price
# 0            1080.0
# 1           54000.0
# 2             990.0
# 4            2250.0
# 5            1170.0
# 6            1980.0
# 7            1710.0
# 8            1620.0
# 9            1260.0

# %%
df = pd.read_csv('discounted_products.csv')

df
# Out:
#     Unnamed: 0 EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  \
# 0            0       E101        Alice  25.0  50000.0   1200      85      90
# 1            1       E102          Bob  30.0      NaN  60000    1500      78
# 2            2       E103      Charlie  22.0  52000.0   1100      92      95
# 3            3       E101        Alice  25.0  50000.0   1200      85      90
# 4            4       E104        David  45.0  80000.0   2500      88      85
# 5            5       E105          Eve  29.0  58000.0   1300      76      79
# 6            6       E106        Frank   NaN  75000.0   2200      90      91
# 7            7       E107        Grace  34.0      NaN   1900      81      83
# 8            8       E108        Heidi  38.0      NaN   1800      84      86
# 9            9       E109         Ivan  26.0  53000.0   1400      95      92
# 10          10       E102          Bob  30.0      NaN  60000    1500      78
#
#     Marks3  Discounted_Price
# 0       88            1080.0
# 1       82           54000.0
# 2       90             990.0
# 3       88            1080.0
# 4       89            2250.0
# 5       81            1170.0
# 6       92            1980.0
# 7       80            1710.0
# 8       88            1620.0
# 9       94            1260.0
# 10      82           54000.0

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Salary'].isna().sum()
# Out:
# np.int64(4)

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

df
# Out:
#     Unnamed: 0 EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  \
# 0            0       E101        Alice  25.0  50000.0   1200      85      90
# 1            1       E102          Bob  30.0      NaN  60000    1500      78
# 2            2       E103      Charlie  22.0  52000.0   1100      92      95
# 3            3       E101        Alice  25.0  50000.0   1200      85      90
# 4            4       E104        David  45.0  80000.0   2500      88      85
# 5            5       E105          Eve  29.0  58000.0   1300      76      79
# 6            6       E106        Frank  30.4  75000.0   2200      90      91
# 7            7       E107        Grace  34.0      NaN   1900      81      83
# 8            8       E108        Heidi  38.0      NaN   1800      84      86
# 9            9       E109         Ivan  26.0  53000.0   1400      95      92
# 10          10       E102          Bob  30.0      NaN  60000    1500      78
#
#     Marks3  Discounted_Price
# 0       88            1080.0
# 1       82           54000.0
# 2       90             990.0
# 3       88            1080.0
# 4       89            2250.0
# 5       81            1170.0
# 6       92            1980.0
# 7       80            1710.0
# 8       88            1620.0
# 9       94            1260.0
# 10      82           54000.0

# %%
df = df.dropna(subset=['Salary'])

df
# Out:
#    Unnamed: 0 EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  \
# 0           0       E101        Alice  25.0  50000.0   1200      85      90
# 2           2       E103      Charlie  22.0  52000.0   1100      92      95
# 3           3       E101        Alice  25.0  50000.0   1200      85      90
# 4           4       E104        David  45.0  80000.0   2500      88      85
# 5           5       E105          Eve  29.0  58000.0   1300      76      79
# 6           6       E106        Frank  30.4  75000.0   2200      90      91
# 9           9       E109         Ivan  26.0  53000.0   1400      95      92
#
#    Marks3  Discounted_Price
# 0      88            1080.0
# 2      90             990.0
# 3      88            1080.0
# 4      89            2250.0
# 5      81            1170.0
# 6      92            1980.0
# 9      94            1260.0

# %%
df = pd.read_csv('discounted_products.csv')

df
# Out:
#     Unnamed: 0 EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  \
# 0            0       E101        Alice  25.0  50000.0   1200      85      90
# 1            1       E102          Bob  30.0      NaN  60000    1500      78
# 2            2       E103      Charlie  22.0  52000.0   1100      92      95
# 3            3       E101        Alice  25.0  50000.0   1200      85      90
# 4            4       E104        David  45.0  80000.0   2500      88      85
# 5            5       E105          Eve  29.0  58000.0   1300      76      79
# 6            6       E106        Frank   NaN  75000.0   2200      90      91
# 7            7       E107        Grace  34.0      NaN   1900      81      83
# 8            8       E108        Heidi  38.0      NaN   1800      84      86
# 9            9       E109         Ivan  26.0  53000.0   1400      95      92
# 10          10       E102          Bob  30.0      NaN  60000    1500      78
#
#     Marks3  Discounted_Price
# 0       88            1080.0
# 1       82           54000.0
# 2       90             990.0
# 3       88            1080.0
# 4       89            2250.0
# 5       81            1170.0
# 6       92            1980.0
# 7       80            1710.0
# 8       88            1620.0
# 9       94            1260.0
# 10      82           54000.0

# %%
print(df['Marks1'].max())
print(df['Marks1'].min())
print(df['Marks1'].mean())
# Out:
# 1500
# 76
# 343.27272727272725

# %%
print(df['Marks2'].max())
print(df['Marks2'].min())
print(df['Marks2'].mean())
# Out:
# 95
# 78
# 86.0909090909091

# %%
print(df['Marks3'].max())
print(df['Marks3'].min())
print(df['Marks3'].mean())
# Out:
# 94
# 80
# 86.72727272727273

# %%
df['Total Marks'] = df['Marks1'] + df['Marks2'] + df['Marks3']

df
# Out:
#     Unnamed: 0 EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  \
# 0            0       E101        Alice  25.0  50000.0   1200      85      90
# 1            1       E102          Bob  30.0      NaN  60000    1500      78
# 2            2       E103      Charlie  22.0  52000.0   1100      92      95
# 3            3       E101        Alice  25.0  50000.0   1200      85      90
# 4            4       E104        David  45.0  80000.0   2500      88      85
# 5            5       E105          Eve  29.0  58000.0   1300      76      79
# 6            6       E106        Frank   NaN  75000.0   2200      90      91
# 7            7       E107        Grace  34.0      NaN   1900      81      83
# 8            8       E108        Heidi  38.0      NaN   1800      84      86
# 9            9       E109         Ivan  26.0  53000.0   1400      95      92
# 10          10       E102          Bob  30.0      NaN  60000    1500      78
#
#     Marks3  Discounted_Price  Total Marks
# 0       88            1080.0          263
# 1       82           54000.0         1660
# 2       90             990.0          277
# 3       88            1080.0          263
# 4       89            2250.0          262
# 5       81            1170.0          236
# 6       92            1980.0          273
# 7       80            1710.0          244
# 8       88            1620.0          258
# 9       94            1260.0          281
# 10      82           54000.0         1660

# %%
df['Total Marks'].std()
# Out:
# 565.7162636066696

# %%
plt.hist(df['Age'], edgecolor='black')
# Out:
# (array([1., 3., 0., 3., 0., 1., 1., 0., 0., 1.]),
#  array([22. , 24.3, 26.6, 28.9, 31.2, 33.5, 35.8, 38.1, 40.4, 42.7, 45. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['Age'], df['Salary'])

# %%
plt.scatter(df['Price'], df['Discounted_Price'])
